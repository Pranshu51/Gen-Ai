# %%
import pandas as pd
df = pd.read_csv(r'D:\csv files\Simple linear regression.csv')

# %%
df.head(10)
# Out:
#     SAT   GPA
# 0  1714  2.40
# 1  1664  2.52
# 2  1760  2.54
# 3  1685  2.74
# 4  1693  2.83
# 5  1670  2.91
# 6  1764  3.00
# 7  1764  3.00
# 8  1792  3.01
# 9  1850  3.01

# %%
import matplotlib.pyplot as plt
plt.scatter(df['SAT'],df['GPA'])
plt.xlabel('SAT')
plt.ylabel('GPA')
plt.show()

# %%
x = df[['SAT']]
y= df[['GPA']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.2, random_state = 0)

# %%
x_train.shape
# Out:
# (67, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()
