# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np

# %%
s1 = pd.Series(data=[10,20,30,40])
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s2 = pd.Series(data=[100,200,300,400])
s2 #one table  one column
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64

# %%
s3 = pd.Series(data=[1000,2000,3000,4000],index=list('vwxy'))
s3 # customized index
# Out:
# v    1000
# w    2000
# x    3000
# y    4000
# dtype: int64

# %%
df = pd.DataFrame({'c1':s1, 'c2':s2})
df #ye ek table h
# Out:
#      c1      c2
# 0  10.0     NaN
# 1  20.0     NaN
# 2  30.0     NaN
# 3  40.0     NaN
# v   NaN  1000.0
# w   NaN  2000.0
# x   NaN  3000.0
# y   NaN  4000.0

# %%
df = pd.DataFrame(data=np.random.randint(1,100,size=(1000,5)),columns = list('abcde'))
df
# Out:
#       a   b   c   d   e
# 0    65   4  51  52  52
# 1    45  27  92  87  12
# 2    91  25  17  60  17
# 3    25  50  90  17  18
# 4    48  13  20  36  57
# ..   ..  ..  ..  ..  ..
# 995  82  80  32  94  31
# 996   1  40  16  96  92
# 997  73  83  13  40  65
# 998  14  18   5  83  29
# 999  34   6  80  13  84
#
# [1000 rows x 5 columns]

# %%
dataset = pd.read_csv(r'c:\Users\DELL\Downloads\zoo_data-1.csv')

# %%
dataset
# Out:
#     animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0      aardvark     1         0     0     1         0        0         1
# 1      antelope     1         0     0     1         0        0         0
# 2          bass     0         0     1     0         0        1         1
# 3          bear     1         0     0     1         0        0         1
# 4          boar     1         0     0     1         0        0         1
# ..          ...   ...       ...   ...   ...       ...      ...       ...
# 96      wallaby     1         0     0     1         0        0         0
# 97         wasp     1         0     1     0         1        0         0
# 98         wolf     1         0     0     1         0        0         1
# 99         worm     0         0     1     0         0        0         0
# 100        wren     0         1     1     0         1        0         0
#
#      toothed  backbone  breathes  venomous  fins  legs  tail  domestic  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   animal_name  101 non-null    object
#  1   hair         101 non-null    int64
#  2   feathers     101 non-null    int64
#  3   eggs         101 non-null    int64
#  4   milk         101 non-null    int64
#  5   airborne     101 non-null    int64
#  6   aquatic      101 non-null    int64
#  7   predator     101 non-null    int64
#  8   toothed      101 non-null    int64
#  9   backbone     101 non-null    int64
#  10  breathes     101 non-null    int64
#  11  venomous     101 non-null    int64
#  12  fins         101 non-null    int64
#  13  legs         101 non-null    int64
#  14  tail         101 non-null    int64
#  15  domestic     101 non-null    int64
#  16  catsize      101 non-null    int64
# dtypes: int64(16), object(1)
# memory usage: 13.5+ KB

# %%
dataset.head()
# Out:
#   animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0    aardvark     1         0     0     1         0        0         1
# 1    antelope     1         0     0     1         0        0         0
# 2        bass     0         0     1     0         0        1         1
# 3        bear     1         0     0     1         0        0         1
# 4        boar     1         0     0     1         0        0         1
#
#    toothed  backbone  breathes  venomous  fins  legs  tail  domestic  catsize
# 0        1         1         1         0     0     4     0         0        1
# 1        1         1         1         0     0     4     1         0        1
# 2        1         1         0         0     1     0     1         0        0
# 3        1         1         1         0     0     4     0         0        1
# 4        1         1         1         0     0     4     1         0        1

# %%
dataset.tail()
# Out:
#     animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 96      wallaby     1         0     0     1         0        0         0
# 97         wasp     1         0     1     0         1        0         0
# 98         wolf     1         0     0     1         0        0         1
# 99         worm     0         0     1     0         0        0         0
# 100        wren     0         1     1     0         1        0         0
#
#      toothed  backbone  breathes  venomous  fins  legs  tail  domestic  \
# 96         1         1         1         0     0     2     1         0
# 97         0         0         1         1     0     6     0         0
# 98         1         1         1         0     0     4     1         0
# 99         0         0         1         0     0     0     0         0
# 100        0         1         1         0     0     2     1         0
#
#      catsize
# 96         1
# 97         0
# 98         1
# 99         0
# 100        0

# %%
dataset.head(10)
# Out:
#   animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0    aardvark     1         0     0     1         0        0         1
# 1    antelope     1         0     0     1         0        0         0
# 2        bass     0         0     1     0         0        1         1
# 3        bear     1         0     0     1         0        0         1
# 4        boar     1         0     0     1         0        0         1
# 5     buffalo     1         0     0     1         0        0         0
# 6        calf     1         0     0     1         0        0         0
# 7        carp     0         0     1     0         0        1         0
# 8     catfish     0         0     1     0         0        1         1
# 9        cavy     1         0     0     1         0        0         0
#
#    toothed  backbone  breathes  venomous  fins  legs  tail  domestic  catsize
# 0        1         1         1         0     0     4     0         0        1
# ...

# %%
dataset.hair.value_counts() # 'Temporery'kitne onse category ke log h idher
# Out:
# hair
# 0    58
# 1    43
# Name: count, dtype: int64

# %%
dataset.rename(columns={'hair':'hairs'})
# Out:
#     animal_name  hairs  feathers  eggs  milk  airborne  aquatic  predator  \
# 0      aardvark      1         0     0     1         0        0         1
# 1      antelope      1         0     0     1         0        0         0
# 2          bass      0         0     1     0         0        1         1
# 3          bear      1         0     0     1         0        0         1
# 4          boar      1         0     0     1         0        0         1
# ..          ...    ...       ...   ...   ...       ...      ...       ...
# 96      wallaby      1         0     0     1         0        0         0
# 97         wasp      1         0     1     0         1        0         0
# 98         wolf      1         0     0     1         0        0         1
# 99         worm      0         0     1     0         0        0         0
# 100        wren      0         1     1     0         1        0         0
#
#      toothed  backbone  breathes  venomous  fins  legs  tail  domestic  \
# ...

# %%
dataset
# Out:
#     animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0      aardvark     1         0     0     1         0        0         1
# 1      antelope     1         0     0     1         0        0         0
# 2          bass     0         0     1     0         0        1         1
# 3          bear     1         0     0     1         0        0         1
# 4          boar     1         0     0     1         0        0         1
# ..          ...   ...       ...   ...   ...       ...      ...       ...
# 96      wallaby     1         0     0     1         0        0         0
# 97         wasp     1         0     1     0         1        0         0
# 98         wolf     1         0     0     1         0        0         1
# 99         worm     0         0     1     0         0        0         0
# 100        wren     0         1     1     0         1        0         0
#
#      toothed  backbone  breathes  venomous  fins  legs  tail  domestic  \
# ...

# %%
dataset.rename(columns={'hair':'hairs'},inplace =True)
dataset #Permanent Changes
# Out:
#     animal_name  hairs  feathers  eggs  milk  airborne  aquatic  predator  \
# 0      aardvark      1         0     0     1         0        0         1
# 1      antelope      1         0     0     1         0        0         0
# 2          bass      0         0     1     0         0        1         1
# 3          bear      1         0     0     1         0        0         1
# 4          boar      1         0     0     1         0        0         1
# ..          ...    ...       ...   ...   ...       ...      ...       ...
# 96      wallaby      1         0     0     1         0        0         0
# 97         wasp      1         0     1     0         1        0         0
# 98         wolf      1         0     0     1         0        0         1
# 99         worm      0         0     1     0         0        0         0
# 100        wren      0         1     1     0         1        0         0
#
#      toothed  backbone  breathes  venomous  fins  legs  tail  domestic  \
# ...

# %%
dataset.columns
# Out:
# Index(['animal_name', 'hairs', 'feathers', 'eggs', 'milk', 'airborne',
#        'aquatic', 'predator', 'toothed', 'backbone', 'breathes', 'venomous',
#        'fins', 'legs', 'tail', 'domestic', 'catsize'],
#       dtype='object')

# %%
dataset[['hairs','feathers']] #selection of columns
# Out:
#      hairs  feathers
# 0        1         0
# 1        1         0
# 2        0         0
# 3        1         0
# 4        1         0
# ..     ...       ...
# 96       1         0
# 97       1         0
# 98       1         0
# 99       0         0
# 100      0         1
#
# [101 rows x 2 columns]

# %%
dataset.loc[50] #datset ke 50 row ki data entry
# Out:
# animal_name    mongoose
# hairs                 1
# feathers              0
# eggs                  0
# milk                  1
# airborne              0
# aquatic               0
# predator              1
# toothed               1
# backbone              1
# breathes              1
# venomous              0
# fins                  0
# legs                  4
# tail                  1
# domestic              0
# catsize               1
# Name: 50, dtype: object

# %%
dataset.loc[50:60] # 50 se 60 ke beech ki data entries
# Out:
#    animal_name  hairs  feathers  eggs  milk  airborne  aquatic  predator  \
# 50    mongoose      1         0     0     1         0        0         1
# 51        moth      1         0     1     0         1        0         0
# 52        newt      0         0     1     0         0        1         1
# 53     octopus      0         0     1     0         0        1         1
# 54     opossum      1         0     0     1         0        0         1
# 55        oryx      1         0     0     1         0        0         0
# 56     ostrich      0         1     1     0         0        0         0
# 57    parakeet      0         1     1     0         1        0         0
# 58     penguin      0         1     1     0         0        1         1
# 59    pheasant      0         1     1     0         1        0         0
# 60        pike      0         0     1     0         0        1         1
#
#     toothed  backbone  breathes  venomous  fins  legs  tail  domestic  catsize
# ...

# %%
dataset=pd.read_csv(r'D:\csv files\adult.csv')

# %%
dataset
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
dataset[(dataset['fnlwgt']>1000000)]
# Out:
#        age     workclass   fnlwgt     education  education.num  \
# 2351    31       Private  1033222     Bachelors             13
# 4586    31     State-gov  1033222  Some-college             10
# 8882    30       Private  1184622  Some-college             10
# 11415   35       Private  1226583     Bachelors             13
# 12711   23       Private  1038553       HS-grad              9
# 16804   25       Private  1484705  Some-college             10
# 17793   29       Private  1268339       HS-grad              9
# 18814   45       Private  1366120     Assoc-voc             11
# 20027   39       Private  1455435    Assoc-acdm             12
# 26064   33       Private  1161363  Some-college             10
# 28039   42  Self-emp-inc  1097453     Bachelors             13
# 28319   24       Private  1085515       HS-grad              9
# 29611   42     Local-gov  1125613       HS-grad              9
#
#               marital.status         occupation   relationship   race     sex  \
# ...

# %%
example = pd.read_csv(r'D:\csv files\homes.csv')

# %%
example
# Out:
#     Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0    142      160         28        10        5         3      60      0.28
# 1    175      180         18         8        4         1      12      0.43
# 2    129      132         13         6        3         1      41      0.33
# 3    138      140         17         7        3         1      22      0.46
# 4    232      240         25         8        4         3       5      2.05
# 5    135      140         18         7        4         3       9      0.57
# 6    150      160         20         8        4         3      18      4.00
# 7    207      225         22         8        4         2      16      2.22
# 8    271      285         30        10        5         2      30      0.53
# 9     89       90         10         5        3         1      43      0.30
# 10   153      157         22         8        3         3      18      0.38
# ...

# %%
taxes_data = example[' "Taxes\"'].notnull()  # Include the quotes in the name

# %%
taxes_data
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# 30    True
# 31    True
# 32    True
# 33    True
# 34    True
# 35    True
# 36    True
# 37    True
# 38    True
# 39    True
# 40    True
# 41    True
# 42    True
# 43    True
# 44    True
# 45    True
# 46    True
# 47    True
# 48    True
# 49    True
# Name:  "Taxes", dtype: bool

# %%
print(example.columns.tolist())  # List all column names
# Out:
# ['Sell', ' "List"', ' "Living"', ' "Rooms"', ' "Beds"', ' "Baths"', ' "Age"', ' "Acres"', ' "Taxes"']

# %%
# Print raw column names with special characters revealed
print([repr(col) for col in example.columns])
# Out:
# ["'Sell'", '\' "List"\'', '\' "Living"\'', '\' "Rooms"\'', '\' "Beds"\'', '\' "Baths"\'', '\' "Age"\'', '\' "Acres"\'', '\' "Taxes"\'']

# %%
example1 = pd.read_csv(r'D:\csv files\car-sales-extended-missing-data.csv')

# %%
example1
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
example1['Make'].notnull() # true :present , False :Absent
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 995     True
# 996    False
# 997     True
# 998     True
# 999     True
# Name: Make, Length: 1000, dtype: bool

# %%
example1[example1['Make'].isnull()] # list jo NAN h
# Out:
#     Make Colour  Odometer (KM)  Doors    Price
# 8    NaN  White       130538.0    4.0   9374.0
# 13   NaN  White       134181.0    4.0  11121.0
# 40   NaN  White       177894.0    4.0   9229.0
# 54   NaN  White       109384.0    4.0   9918.0
# 73   NaN    Red       227262.0    4.0  12001.0
# 77   NaN  White       126669.0    4.0  18484.0
# 89   NaN   Blue        90249.0    4.0  35988.0
# 122  NaN   Blue       174008.0    4.0  19000.0
# 123  NaN  White       138274.0    4.0   7994.0
# 125  NaN   Blue        83784.0    4.0  11648.0
# 156  NaN  White       150826.0    4.0  12392.0
# 200  NaN  White        66461.0    3.0  25873.0
# 239  NaN  Black       224479.0    4.0  10456.0
# 256  NaN   Blue        65719.0    4.0      NaN
# 265  NaN  White       113250.0    4.0   9675.0
# 320  NaN   Blue       179468.0    4.0   7813.0
# 342  NaN    Red        97345.0    4.0   6962.0
# 344  NaN   Blue        73926.0    4.0  29635.0
# 356  NaN   Blue        96363.0    4.0   7469.0
# ...

# %%
example1['Make'] = example1['Make'].fillna('BMW')  # No inplace=True needed  # for filing wwith max value example['Make'].fillna(example1['Make'].max())

# %%
example1
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     BMW  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
#example1['Make'] = example1['Make'].fillna(example['Make'].std()) min() bhi le skte h

# %%
example1.drop(['Colour'],axis='columns') #temporery delete
# Out:
#        Make  Odometer (KM)  Doors    Price
# 0     Honda        35431.0    4.0  15323.0
# 1       BMW       192714.0    5.0  19943.0
# 2     Honda        84714.0    4.0  28343.0
# 3    Toyota       154365.0    4.0  13434.0
# 4    Nissan       181577.0    3.0  14043.0
# ..      ...            ...    ...      ...
# 995  Toyota        35820.0    4.0  32042.0
# 996     BMW       155144.0    3.0   5716.0
# 997  Nissan        66604.0    4.0  31570.0
# 998   Honda       215883.0    4.0   4001.0
# 999  Toyota       248360.0    4.0  12732.0
#
# [1000 rows x 4 columns]

# %%
example1
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     BMW  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
example1.drop(columns=['Colour'], inplace=True)

# %%
example1
# Out:
#        Make  Odometer (KM)  Doors    Price
# 0     Honda        35431.0    4.0  15323.0
# 1       BMW       192714.0    5.0  19943.0
# 2     Honda        84714.0    4.0  28343.0
# 3    Toyota       154365.0    4.0  13434.0
# 4    Nissan       181577.0    3.0  14043.0
# ..      ...            ...    ...      ...
# 995  Toyota        35820.0    4.0  32042.0
# 996     BMW       155144.0    3.0   5716.0
# 997  Nissan        66604.0    4.0  31570.0
# 998   Honda       215883.0    4.0   4001.0
# 999  Toyota       248360.0    4.0  12732.0
#
# [1000 rows x 4 columns]

# %%
data1 = pd.DataFrame(
    data=np.random.randint(1, 100, size=(100, 4)),
    columns=list('abcd')
)  # This parenthesis closes pd.DataFrame()

# %%
data2 = pd.DataFrame(data=np.random.randint(1,100,size=(100,3)), columns=list('xyz'))

# %%
data1
# Out:
#      a   b   c   d
# 0   89  47  76  33
# 1    1  40  65  72
# 2   32  52  63  87
# 3    9  54  25  89
# 4   80   7  42  49
# ..  ..  ..  ..  ..
# 95  28  89  47  13
# 96  79  15  41   7
# 97  39  30  42  65
# 98   4  70  31  42
# 99  66  94   5  58
#
# [100 rows x 4 columns]

# %%
data2
# Out:
#      x   y   z
# 0   49  67  71
# 1    9  71  41
# 2    5  66  96
# 3   63  29  46
# 4   20  67  45
# ..  ..  ..  ..
# 95  19  74  75
# 96   3   7  93
# 97  69  95  54
# 98  69  31  75
# 99  28  10  23
#
# [100 rows x 3 columns]

# %%
combined_data = pd.concat([data1, data2], axis=0)  # Stack vertically (row-wise)

# %%
combined_data  #column ka bhi addition and row kka bhi additon means 100+100=200 and 4+3=7
# Out:
#      a   b   c   d   x   y   z
# 0   89  47  76  33  49  67  71
# 1    1  40  65  72   9  71  41
# 2   32  52  63  87   5  66  96
# 3    9  54  25  89  63  29  46
# 4   80   7  42  49  20  67  45
# ..  ..  ..  ..  ..  ..  ..  ..
# 95  28  89  47  13  19  74  75
# 96  79  15  41   7   3   7  93
# 97  39  30  42  65  69  95  54
# 98   4  70  31  42  69  31  75
# 99  66  94   5  58  28  10  23
#
# [100 rows x 7 columns]

# %%
combined_data = pd.concat([data1, data2], axis=1) 
combined_data
#only column ka ddtion hoga no rows addiotn
# Out:
#      a   b   c   d   x   y   z
# 0   89  47  76  33  49  67  71
# 1    1  40  65  72   9  71  41
# 2   32  52  63  87   5  66  96
# 3    9  54  25  89  63  29  46
# 4   80   7  42  49  20  67  45
# ..  ..  ..  ..  ..  ..  ..  ..
# 95  28  89  47  13  19  74  75
# 96  79  15  41   7   3   7  93
# 97  39  30  42  65  69  95  54
# 98   4  70  31  42  69  31  75
# 99  66  94   5  58  28  10  23
#
# [100 rows x 7 columns]

# %%
data3 = pd.DataFrame(data=np.random.randint(1,100,size=(100,3)), columns=list('afg'))

# %%
data4 = pd.DataFrame(data=np.random.randint(1,100,size=(100,3)), columns=list('aqr'))

# %%
 data3.merge(data4, on='a')
# Out:
#      a   f   g   q   r
# 0   47  39  54  49  51
# 1   99  88  73  35   2
# 2   66  89  69  42  47
# 3   30  88  82  20  22
# 4   68  79  44  22  75
# ..  ..  ..  ..  ..  ..
# 91  87  94  32   8  77
# 92  87  94  32  39  91
# 93  19  54  29  44  31
# 94  68  74  32  22  75
# 95  99  50  89  35   2
#
# [96 rows x 5 columns]
